# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('heart_disease.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.shape
# Out:
# (303, 14)

# %% [markdown]
# Exploring The Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     303 non-null    int64
#  1   sex_male                303 non-null    int64
#  2   chest_pain              303 non-null    int64
#  3   resting_blood_pressure  303 non-null    int64
#  4   serum_cholestoral       303 non-null    int64
#  5   fasting_blood_sugar     303 non-null    int64
#  6   restecg                 303 non-null    int64
#  7   maximum_heartrate       303 non-null    int64
#  8   exang                   303 non-null    int64
#  9   oldpeak                 303 non-null    float64
#  10  slope                   303 non-null    int64
#  11  major_vessels           303 non-null    int64
#  12  thal                    303 non-null    int64
#  13  target                  303 non-null    int64
# dtypes: float64(1), int64(13)
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#Renaming Gender Column
data.rename(columns = {'sex':'sex_male','cp' : 'chest_pain', 'trestbps' : 'resting_blood_pressure',
                      'chol' : 'serum_cholestoral','fbs' : 'fasting_blood_sugar', 'thalach' : 'maximum_heartrate',
                      'ca' : 'major_vessels'}, inplace = True)

# %%
data.columns
# Out:
# Index(['age', 'sex_male', 'chest_pain', 'resting_blood_pressure',
#        'serum_cholestoral', 'fasting_blood_sugar', 'restecg',
#        'maximum_heartrate', 'exang', 'oldpeak', 'slope', 'major_vessels',
#        'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x = 'sex_male', data = data)
# Out:
# <AxesSubplot:xlabel='sex_male', ylabel='count'>

# %%
sns.countplot(x = 'chest_pain', data = data)
# Out:
# <AxesSubplot:xlabel='chest_pain', ylabel='count'>

# %%
sns.histplot(x = data['resting_blood_pressure'], kde = False)
# Out:
# <AxesSubplot:xlabel='resting_blood_pressure', ylabel='Count'>

# %%
sns.countplot(x = 'target', data = data)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x = data['resting_blood_pressure'], y = data['maximum_heartrate'], hue = data['target'])
# Out:
# <AxesSubplot:xlabel='resting_blood_pressure', ylabel='maximum_heartrate'>

# %%
sns.lmplot(x = 'resting_blood_pressure', y = 'maximum_heartrate', hue = 'target', data = data)

# %%
sns.swarmplot(x = data['target'], y = data['maximum_heartrate'])
#Maximum Cases are there when Heartrate is between 140 - 200
# Out:
# <AxesSubplot:xlabel='target', ylabel='maximum_heartrate'>

# %%
columns =  ['age', 'sex_male', 'chest_pain', 'resting_blood_pressure',
       'serum_cholestoral', 'fasting_blood_sugar', 'restecg',
       'maximum_heartrate', 'exang', 'oldpeak', 'slope', 'major_vessels',
       'thal']

# %%
#for col in data.columns:
    #sns.scatterplot(x = 'target', y = col, data = data)
    #plt.show()

# %%
sns.barplot(x = 'thal',y = 'target', data = data)
# Out:
# <AxesSubplot:xlabel='thal', ylabel='target'>

# %%
sns.swarmplot(x = 'sex_male', y = 'maximum_heartrate', hue = 'target', data = data)
#In males there is less chance of disease if hear rate is less than 140 and in Womens the one with 160 or above have chances of disease
# Out:
# <AxesSubplot:xlabel='sex_male', ylabel='maximum_heartrate'>

# %%
sns.regplot(x = data.resting_blood_pressure, y = data.serum_cholestoral)
# Out:
# <AxesSubplot:xlabel='resting_blood_pressure', ylabel='serum_cholestoral'>

# %% [markdown]
# # Splitting Dataset for Model Training

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
x = data.drop(columns = 'target')
y = data.target
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %%
#train_test_splitting of the dataset
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier(base_estimator=None)
adb.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
y_pred=adb.predict(X_test)
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.1639344262295

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100,random_state=0)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=0)

# %%
y_pred_rfc=rfc.predict(X_test)
print(accuracy_score(y_test,y_pred_rfc)*100)
# Out:
# 86.88524590163934
